# %% [markdown]
# # 📦 Chapter 2 Exercise: Requirements Generator
#
# A good project always lists its dependencies. In this exercise, you will create a `requirements.txt` file programmatically based on the libraries we just verified.
#
# **Your Goal:**
# 1.  Use Python's file I/O to write a text file.
# 2.  List the core libraries (`numpy`, `pandas`, `matplotlib`, `open3d`, `laspy`, `scikit-learn`).

# %%
# List of libraries
libraries = [
    "numpy",
    "pandas",
    "matplotlib",
    "open3d",
    "laspy",
    "scikit-learn"
]

# TODO: Open a file called 'requirements.txt' in write mode ('w')
# TODO: Iterate through the libraries list and write each one to the file followed by a newline (\n)

print("Finished creating requirements.txt! Check your folder.")

# %% [markdown]
# ## Challenge
# Can you modify the script to verify if the file exists after writing it?

# %%
import os

# TODO: Use os.path.exists() to check if 'requirements.txt' exists
if ...:
    print("File confirmed.")
else:
    print("Something went wrong.")
