# %% [markdown]
# # 🛠️ Chapter 15 Exercise: Preparing Data for Deep Learning
#
# Deep Learning models expect fixed-size inputs or specific formats. For point clouds, we often:
# 1.  **Block/Tile** the data (cut into grid cells like 10x10m).
# 2.  **Normalize** coordinates (center them in the block).
# 3.  **Subsample** to a fixed number of points (e.g., 4096 points per block).
#
# **Your Task:**
# Write a function `prepare_blocks(points, block_size=10, points_per_block=4096)` that takes a massive point cloud and returns a list of "ready-to-feed" mini-clouds.

# %%
import numpy as np
import laspy
import matplotlib.pyplot as plt

# %%
# Load Data
try:
    las = laspy.read("../DATA/indoor_train.las")
    points = np.vstack((las.x, las.y, las.z)).transpose()
except:
    points = np.random.rand(100000, 3) * 100 # Dummy 100x100m area

# %%
def prepare_blocks(points, block_size=10, points_per_block=4096):
    blocks = []
    
    # TODO: Determine min/max X and Y
    
    # TODO: Iterate over grid X and Y with step 'block_size'
    
    # TODO: Filter points inside the current block square
    
    # TODO: If existing points > points_per_block, random sample. If less, duplicate (padding).
    
    # TODO: Center points (subtract min X, min Y of the block)
    
    # TODO: Scale to [0, 1] if needed
    
    # blocks.append(normalized_points)
    
    return blocks

# Run
dataset = prepare_blocks(points)
print(f"Created {len(dataset)} blocks ready for training.")
