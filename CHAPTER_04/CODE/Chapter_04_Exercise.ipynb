# %% [markdown]
# # 📦 Chapter 4 Exercise: Format Converter
#
# Understanding file formats is key. Your task is to build a simple mechanism to convert a raw NumPy array into a standard `.ply` file.
#
# **Your Goal:**
# 1.  Generate a random spiral of points in Numpy.
# 2.  Save it as a `.ply` file using Open3D.
# 3.  Load it back to verify.

# %%
import numpy as np
import open3d as o3d

# 1. Generate Data: A Helix/Spiral
t = np.linspace(0, 10 * np.pi, 500)
x = np.cos(t)
y = np.sin(t)
z = t / 10.0

# Stack into (N, 3) array
points = np.vstack((x, y, z)).T

# TODO: Create an Open3D PointCloud object named 'pcd'
pcd = o3d.geometry.PointCloud()
pcd.points = ... # Assign the points

# TODO: Create some colors (optional, maybe based on Z height)
# colors = ...
# pcd.colors = ...

# 2. Save to Disk
output_filename = "my_spiral.ply"
# TODO: Use o3d.io.write_point_cloud to save it

print(f"Saved {output_filename}")

# %% [markdown]
# ## Verification
#
# Now load it back and check the Number of points.

# %%
# TODO: Load the file back
loaded_pcd = ...

print(f"Loaded PCD has {len(loaded_pcd.points)} points.")

# Visualize
o3d.visualization.draw_geometries([loaded_pcd])
