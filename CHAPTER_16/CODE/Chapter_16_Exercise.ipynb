# %% [markdown]
# # 🛠️ Chapter 16 Exercise: Data Augmentation
#
# To train robust Deep Learning models, we need to artificially increase the size of our dataset using augmentations.
#
# **Your Task:**
# Implement functions for 3 common augmentations:
# 1.  **Rotation**: Rotate the object around the Z-axis (gravity aligned).
# 2.  **Jittering**: Add small random noise to every point.
# 3.  **Scaling**: Randomly scale the object size.
#
# Write a loop to visualize an object, apply augmentation, and visualize the result.

# %%
import numpy as np
import open3d as o3d
import copy

# %%
# 1. Load Object
pcd = o3d.geometry.TriangleMesh.create_cone().sample_points_poisson_disk(1000)
# pcd = o3d.io.read_point_cloud("../DATA/your_object.ply") # Or load real data
o3d.visualization.draw_geometries([pcd], window_name="Original")

# %%
def rotate_point_cloud(pcd):
    # TODO: Generate random angle
    # TODO: Create rotation matrix
    # TODO: Apply to pcd
    return pcd

def jitter_point_cloud(pcd, sigma=0.01, clip=0.05):
    # TODO: Add Gaussian noise
    return pcd

def scale_point_cloud(pcd, scale_low=0.8, scale_high=1.25):
    # TODO: Random scale
    return pcd

# Test loop
aug_pcd = copy.deepcopy(pcd)
aug_pcd = rotate_point_cloud(aug_pcd)
aug_pcd = jitter_point_cloud(aug_pcd)
aug_pcd.paint_uniform_color([1, 0, 0]) # Red for augmented

o3d.visualization.draw_geometries([pcd, aug_pcd], window_name="Augmented vs Original")
