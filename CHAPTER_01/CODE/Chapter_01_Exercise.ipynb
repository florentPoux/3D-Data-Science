# %% [markdown]
# # 💪 Chapter 1 Exercise: Build a Pyramid
#
# Now that you've mastered the cube, it's time to build something slightly more complex: a **Square Pyramid**.
#
# **Your Goal:**
# 1. Define the 5 vertices of a pyramid.
# 2. Define the edges connecting them.
# 3. Plot it in 3D.

# %% [markdown]
# ## Task 1: Define Vertices & Edges
#
# A square pyramid has 4 points at the base (just like a square plane) and 1 point at the top (the apex).
#
# *   **Base:** $(1, 1, 0), (1, -1, 0), (-1, -1, 0), (-1, 1, 0)$
# *   **Apex:** $(0, 0, 2)$
#
# > 💡 **Tip:** Define `vertices` as a numpy array.

# %%
import numpy as np
import matplotlib.pyplot as plt

# TODO: Create the vertices array
vertices_pyramid = np.array([
    # Fill this in
    # [x, y, z]
])

# TODO: Create the edges list of pairs (indices)
edges_pyramid = np.array([
    # Base edges: 0-1, 1-2, etc.
    # Apex edges: 0-Apex, 1-Apex, etc.
])

# %% [markdown]
# ## Task 2: Visualization
#
# Use the code we learned in the main notebook to plot this pyramid.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# TODO: Plot vertices (hint: ax.scatter)

# TODO: Plot edges (hint: for loop over edges)

ax.set_title("My First Pyramid")
plt.show()

# %% [markdown]
# ## Task 3: Challenge - Rotation
#
# Can you make the pyramid upside down?
#
# > 💡 **Hint:** You can simply flip the Z coordinate by multiplying it by -1, OR you can define a Rotation Matrix.

# %%
# TODO: Invert the Z axis of vertices_pyramid

# TODO: Plot the new inverted pyramid
