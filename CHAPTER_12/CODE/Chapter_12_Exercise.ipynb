# %% [markdown]
# # 🛠️ Chapter 12 Exercise: Clustering Cars
#
# **Your Task:**
# 1.  Load the `KME_cars.xyz` dataset.
# 2.  This dataset typically contains multiple cars parked next to each other.
# 3.  Use **DBSCAN** to separate individual cars.
# 4.  Tune the `eps` (epsilon) parameter until you get clean clusters for each car.
# 5.  Visualize the result with unique colors for each car.
#
# **Bonus:** Count how many cars are detected.

# %%
import numpy as np
import open3d as o3d
import matplotlib.pyplot as plt

# %%
# 1. Load Data
pcd = o3d.io.read_point_cloud("../DATA/KME_cars.xyz")
o3d.visualization.draw_geometries([pcd])

# %%
# 2. DBSCAN Clustering

# TODO: Experiment with eps. Values between 0.1 and 0.5 are reasonable starting points.
# labels = np.array(pcd.cluster_dbscan(eps=..., min_points=..., print_progress=True))

# TODO: Count cars
# max_label = ...
# print(f"Number of cars: {max_label + 1}")

# TODO: Visualize
