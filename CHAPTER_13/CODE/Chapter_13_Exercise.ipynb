# %% [markdown]
# # 🛠️ Chapter 13 Exercise: Building the Projector
#
# The core of the GeoSAM workflow is the ability to transform 3D data into a 2D representation that image-based AI models can understand.
#
# **Your Task:**
# 1.  Load `room_furnitures.ply` (or any point cloud).
# 2.  Implement a function `point_cloud_to_panorama(pcd)` that:
#     *   Centers the cloud.
#     *   Converts $(x, y, z)$ to spherical $(\theta, \phi, r)$.
#     *   Maps these to pixel coordinates $(u, v)$ on an image of size $W \times H$.
#     *   Handles occlusion (Z-buffering) so only the visible points are drawn.
# 3.  Visualize the resulting panorama using Matplotlib.

# %%
import numpy as np
import open3d as o3d
import matplotlib.pyplot as plt

# %%
# 1. Load Data
pcd = o3d.io.read_point_cloud("../DATA/room_furnitures.ply")
o3d.visualization.draw_geometries([pcd])
points = np.asarray(pcd.points)
colors = np.asarray(pcd.colors)

# %%
# 2. Implement Projection

def project_to_panorama(points, colors, height=200, width=400):
    # TODO: Center points
    
    # TODO: Calculate Theta and Phi
    
    # TODO: Map to X, Y pixels
    
    # TODO: Create image buffer and fill it (handling depth)
    
    panorama = np.zeros((height, width, 3))
    return panorama

# 3. Run and Show
# img = project_to_panorama(points, colors)
# plt.imshow(img)
# plt.show()
